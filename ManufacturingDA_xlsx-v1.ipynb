# %% [markdown]
# ## Mantención Reactiva en Manufactura usando DA

# %%
__author__ = "Marcelo Gallegos"

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mainpath = os.getcwd()

# %%
equipoModelo = pd.read_excel(mainpath + '\Data.xlsx', "equipo_Modelo")
equipos = {'equipo_'+str(i):[] for i in range(1,11)}
for i in range(1,11):
    equipos['equipo_'+str(i)] = pd.read_excel(mainpath + '\Data.xlsx', "equipo_" + str(i))

# %%
equipoModelo = pd.read_excel(mainpath + '\Data.xlsx', "equipo_Modelo")
equipos = {'equipo_'+str(i):[] for i in range(1,11)}
for i in range(1,11):
    equipos['equipo_'+str(i)] = pd.read_excel(mainpath + '\Data.xlsx', "equipo_" + str(i))

# %%
equipos['equipo_1'].mean()
# Out:
# Sensor1     1.115246
# Sensor2     1.078324
# Sensor3     0.848681
# Sensor4     0.974678
# Sensor5     9.065830
# Sensor6     7.609712
# Sensor7     8.058303
# Sensor8     3.930059
# Sensor9     6.186747
# Sensor10    1.366539
# dtype: float64

# %%
for equipo in equipos:
    print(f"Nivel Correlacion de {equipo} respecto a equipoModelo:", round(equipoModelo.corrwith(equipos[equipo],axis=1).sum(),2))
# Out:
# Nivel Correlacion de equipo_1 respecto a equipoModelo: -0.93
# Nivel Correlacion de equipo_2 respecto a equipoModelo: -7.4
# Nivel Correlacion de equipo_3 respecto a equipoModelo: 10.89
# Nivel Correlacion de equipo_4 respecto a equipoModelo: 9.93
# Nivel Correlacion de equipo_5 respecto a equipoModelo: -0.73
# Nivel Correlacion de equipo_6 respecto a equipoModelo: 3.59
# Nivel Correlacion de equipo_7 respecto a equipoModelo: 3.25
# Nivel Correlacion de equipo_8 respecto a equipoModelo: 7.0
# Nivel Correlacion de equipo_9 respecto a equipoModelo: -0.87
# Nivel Correlacion de equipo_10 respecto a equipoModelo: 9.7

# %%
#SENSOR 1 | EquipoModelo vs Equipo1
plt.figure(figsize=(7,5))
plt.scatter(equipoModelo.loc[:,"Sensor1"],equipos['equipo_1'].loc[:,"Sensor1"])
plt.title("Correlacion Lectura Sensor1-equipoModelo vs Sensor1-equipo4")
plt.show()

# %%
#SENSOR 1 | EquipoModelo vs Equipo2
plt.figure(figsize=(7,5))
plt.scatter(equipoModelo.loc[:,"Sensor1"],equipos['equipo_2'].loc[:,"Sensor1"])
plt.title("Correlacion Lectura Sensor1-equipoModelo vs Sensor1-equipo4")
plt.show()

# %%
for equipo in equipos:
    print(f"Nivel Correlacion de {equipo} respecto a equipoModelo:", round(equipoModelo.corrwith(equipos[equipo],axis=1).sum(),2))
# Out:
# Nivel Correlacion de equipo_1 respecto a equipoModelo: -0.93
# Nivel Correlacion de equipo_2 respecto a equipoModelo: -7.4
# Nivel Correlacion de equipo_3 respecto a equipoModelo: 10.89
# Nivel Correlacion de equipo_4 respecto a equipoModelo: 9.93
# Nivel Correlacion de equipo_5 respecto a equipoModelo: -0.73
# Nivel Correlacion de equipo_6 respecto a equipoModelo: 3.59
# Nivel Correlacion de equipo_7 respecto a equipoModelo: 3.25
# Nivel Correlacion de equipo_8 respecto a equipoModelo: 7.0
# Nivel Correlacion de equipo_9 respecto a equipoModelo: -0.87
# Nivel Correlacion de equipo_10 respecto a equipoModelo: 9.7

# %%
plt.figure(figsize=(7,5))
plt.scatter(equipoModelo,equipos['equipo_1'])
plt.title("Correlacion Lectura Sensor1-equipoModelo vs Sensor1-equipo4")
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.scatter(data_equipoModelo,data_equipo1)
plt.title("Correlacion Lectura Sensor1-equipoModelo vs Sensor1-equipo4")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c5b419e2dbdf> in <module>
#       1 plt.figure(figsize=(7,5))
# ----> 2 plt.scatter(data_equipoModelo,data_equipo1)
#       3 plt.title("Correlacion Lectura Sensor1-equipoModelo vs Sensor1-equipo4")
#       4 plt.show()
#
# NameError: name 'data_equipoModelo' is not defined
